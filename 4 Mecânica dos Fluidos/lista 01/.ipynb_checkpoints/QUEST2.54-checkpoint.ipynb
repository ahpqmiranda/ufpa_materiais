# %%
import sympy as sp
import math
import numpy as np
import pandas as pd
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
sp.init_printing()
x, y, tau, R0, r = sp.symbols('x y tau R0 r')
u = sp.Function('u')(y)

# %%
Image(filename='quest2.54.png')

# %% [markdown]
# Dados Utilizados:

# %%
L = 2               # [m] Comprimento da tubulação
Ri = 5e-3           # [m] Raio interno da tubulação
Re = 25e-3          # [m] Raio externo da tubulação
dp = 125e+3         # [Pa] Pressão aplicada para bombear o mel
mi_mel = 5          # [N.s/m²] Coeficiente de viscosidade dinâmica do mel
const = dp * math.pi * (R0 ** 2 - Ri ** 2) #

# %%
u = 1 / (4 * mi_mel) * (dp / L) * (Ri ** 2 - r ** 2 - )
# Out:
#   Input In [5]
#     u = 1 / (4 * mi_mel) * (dp / L) * (Ri ** 2 - r ** 2 - )
#                                                           ^
# SyntaxError: invalid syntax

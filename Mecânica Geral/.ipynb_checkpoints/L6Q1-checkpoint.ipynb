# %%
import pandas as pd
import IPython.display as ipd
import sympy as sy


x, y, z = sy.symbols('x y z')
sy.init_printing()

# %% [markdown]
# # LISTA 6 - QUESTÃO 1

# %%
ipd.Image(filename='L6Q1.png')

# %% [markdown]
# ### Dados Necessários:

# %%
d_bases = 15 # [mm]
d_alma = 7.5 # [mm]
L_base = 100 # [mm]
L_alma = 225 # [mm]

# %% [markdown]
# A secção transversal da viga é uma área composta de três elementos, dos quais 2 são iguais, o que permite simplificar o processo.
# Cálculo dos momentos de inércia em relação ao eixo Y:
# 1. alma
# 2. base 1
# 3. base 2
# base 1 e base 2 são iguais, logo:

# %%
I1y = L_alma * d_alma ** 3 / 12
I2y = d_bases * (L_base/2) ** 3 / 12
I3y = I2y

# %%
data_inertia = pd.DataFrame({
    'momentos de inércia (mm^4)':(I1y, I2y, I3y)
})
data_inertia.T
# Out:
#                                      0         1         2
# momentos de inércia (mm^4)  7910.15625  156250.0  156250.0

# %%
import pandas as pd
import numpy as np
import sympy as sp
import matplotlib.pyplot as plt
from IPython.display import Image

# %%
Image(filename='questão 3 aula online 22-02-25.png', width=500)

# %%
Image(filename='questão 3 gráficos 22-02-25.png', width=500)

# %%
# Dados
D_e = 50e-3  # m (tubos)
T_wall = 180  # °C
metal_tipo  = 'alumínio 224'
k_aleta = 186  # W/m°C (alumínio 224)
T_ar = 25  # °C
L = 1  # m
D_e_aleta = 60e-3  # m
D_entre_aletas = 3e-3  # m
h = 40  # W/m²°C
n_aletas = 250

resposta = 2639 # W

# %%
A = np.pi * D_e**2 / 4
Q_nofim = h*A*(T_wall - T_ar)
Q_nofim
# Out:
# 12.173671532660448

# %%
Image(filename='seleção de curva.png', width=100)

# %%
# a equação que relaciona a proporcionalidade entre a eficiência e o número de aletas é:
# L = R_2c / R_1
# sci = L_c ** (3/2)*(h/k*A_p) ** (1/2)

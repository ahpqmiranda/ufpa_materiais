# %%
import math as m
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd
import sympy as sy
import sympy.physics.quantum.constants as const

x, y, z = sy.symbols('x y z')
sy.init_printing()

# %%
ipd.Image(filename='L6Q2-1.png')

# %%
ipd.Image(filename='L6Q2-2.png')

# %% [markdown]
# ### Dados Necessários:

# %%
X = 4 # [in]
Y = 2 # [in]
y = x ** 0.5 # curva do paraboloide

# %% [markdown]
# Utilizamos o teorema dos eixos paralelos para modelar o produto de inércia para o problema em questão.
# Pontos a se considerar:
#  1. o produto de inércia I_xy é nulo pro exemplo em questão, pois o eixo centroidal confere simetria ao elemento de área.
#  2. vamos trabalhar com a inércia da área.
#
# portanto:

# %%
ipd.Image(filename='L6Q2-3.png')

# %% [markdown]
# o x vai possuir valor 'x' e o y vai possuir valor 'y/2 * y'

# %%
I = x * y / 2 * y
sy.simplify(I)
# Out:
#  2.0
# x
# ────
#  2

# %% [markdown]
# Agora integramos em relação ao eixo X no percurso de 0 a 4

# %%
I = sy.integrate(I, (x, 0, X))
print('Produto de inércia é: {:.3f} in^4'.format(I))
# Out:
# Produto de inércia é: 10.667 in^4

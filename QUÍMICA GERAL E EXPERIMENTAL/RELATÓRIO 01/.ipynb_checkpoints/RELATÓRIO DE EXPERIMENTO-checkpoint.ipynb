# %% [markdown]
# ## Relatório de Cálculos da Solução de Sulfato de Cobre

# %% [markdown]
# #### Bibliotecas utilizadas:

# %%
import sympy as sp
#from sympy.physics.units import *
import numpy as np
import pandas as pd
from IPython.display import Image

# %%
mass = 2.521 # [g] CUSO4.5H2O
molar_CUSO4 = 249.6850 # [g/mol] CUSO4.5H2O
molar_H20 = 18.01528 # [g/mol] H20
vol_H20 = 0.1 # [L] H2O
rho_H20 = 1000 # [g/L] H20

# %%
Image(filename="massa_utilizada.jpeg", width = 400, height = 250)

# %%
df = pd.Series({
    'Massa de CUSO4.5H2O [g]': mass,
    'Massa Molar de CUSO4.5H2O [g/mol]': molar_CUSO4,
    'Volume de Solvente (H20) [L]': vol_H20,
    'Mols de CUSO4.5H2O [mols]': mass/molar_CUSO4,
    'Mols de H20 [mols]': vol_H20 * rho_H20 / molar_H20
})
df
# Out:
# Massa de CUSO4.5H2O [g]                2.521000
# Massa Molar de CUSO4.5H2O [g/mol]    249.685000
# Volume de Solvente (H20) [L]           0.100000
# Mols de CUSO4.5H2O [mols]              0.010097
# Mols de H20 [mols]                     5.550844
# dtype: float64

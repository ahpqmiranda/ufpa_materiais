# %%
import numpy as np
import pandas as pd
import scipy as sp

# %%
# dados da questao

v_rot = 500 # rad/s
theta_0 = 60 # graus
theta_0 = np.deg2rad(theta_0) # rad
L_pb = 500 # mm
L_pb = L_pb / 1000 # m
L_ab = 100 #
L_ab = L_ab / 1000 # m
r_ab = np.array([np.cos(theta_0), np.sin(theta_0)]) * L_pb# mm

# %%
r_ab
# Out:
# array([0.25     , 0.4330127])

# %%
v_b = v_rot * L_ab
v_b
# Out:
# 50.0

# %%
V_c = np.array([0, -v_b]) + v_rot * r_ab
V_c
# Out:
# array([125.        , 166.50635095])

# %%
import numpy as np
import pandas as pd
import scipy as sp
import sympy as sy

# %%
phi_bc = 6 # rad/s
V_e, phi_ab, L_ab, t = sy.symbols('V_e phi_ab L_ab t')
theta_ab = 30 # graus
theta_ab = np.deg2rad(theta_ab) # rad
L_bc = 0.6 # m
L_cd = .6 # m
phi_cd = 6 # rad/s

# %%
V_c = phi_bc * L_bc
print(f'V_c = {V_c:.2f} m/s')
# Out:
# V_c = 3.60 m/s

# %%
V_b = V_c + phi_bc * L_bc
print(f'V_b = {V_b:.2f} m/s')
# Out:
# V_b = 7.20 m/s

# %%
phi_ab = V_b / L_ab
phi_ab
# Out:
# 7.2/L_ab
